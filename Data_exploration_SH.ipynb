# %%
import requests

# %%
resp_nyt = requests.get("https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=Z0yWljtxxgI8qc13dN3ZW6gvLM5apn2G")

# %%
resp_nyt.status_code
# Out:
# 200

# %%
resp_nyt.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 59,
#  'results': [{'list_name': 'Combined Print and E-Book Fiction',
#    'display_name': 'Combined Print & E-Book Fiction',
#    'list_name_encoded': 'combined-print-and-e-book-fiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2019-12-01',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Combined Print and E-Book Nonfiction',
#    'display_name': 'Combined Print & E-Book Nonfiction',
#    'list_name_encoded': 'combined-print-and-e-book-nonfiction',
#    'oldest_published_date': '2011-02-13',
#    'newest_published_date': '2019-12-01',
#    'updated': 'WEEKLY'},
#   {'list_name': 'Hardcover Fiction',
#    'display_name': 'Hardcover Fiction',
#    'list_name_encoded': 'hardcover-fiction',
#    'oldest_published_date': '2008-06-08',
#    'newest_published_date': '2019-12-01',
#    'updated': 'WEEKLY'},
# ...

# %%
# for book_list in resp_nyt.json()['results']:
#     print(book_list['list_name'])

# %%
credentials = {'list': 'combined-print-and-e-book-fiction', 'bestsellers-date': '2008-12-30'}

# %%
resp_nyt_earliest = requests.get("https://api.nytimes.com/svc/books/v3/lists/2011-02-13/combined-print-and-e-book-fiction.json?api-key=Z0yWljtxxgI8qc13dN3ZW6gvLM5apn2G")

# %%
resp_nyt_earliest.status_code
# Out:
# 200

# %%
resp_nyt_earliest.json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company.  All Rights Reserved.',
#  'num_results': 35,
#  'last_modified': '2019-08-29T20:54:03-04:00',
#  'results': {'list_name': 'Combined Print and E-Book Fiction',
#   'list_name_encoded': 'combined-print-and-e-book-fiction',
#   'bestsellers_date': '2011-01-30',
#   'published_date': '2011-02-13',
#   'published_date_description': 'first',
#   'next_published_date': '2011-02-20',
#   'previous_published_date': '',
#   'display_name': 'Combined Print & E-Book Fiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 0,
#     'weeks_on_list': 1,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0316037915',
#     'primary_isbn13': '9780316037914',
#     'publisher': 'Little, Brown',
# ...
